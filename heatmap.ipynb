# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
import seaborn as sns
import requests

# %%
def plot_heatmap(player_id): 
    url = f'https://sofascore.com/api/v1/player/{player_id}/unique-tournament/17/season/52186/heatmap/overall'
    response = requests.get(url)
    data = response.json()
    points_list = data['points']

# Create a dataframe
df = pd.DataFrame(points_list)

pitch = Pitch(pitch_type='opta', pitch_color='#22312b', line_color='white')

# Plot the pitch
fig, ax = pitch.draw()

# Create KDE plot on the pitch
kde = sns.kdeplot(
    data=df,
    x='x',
    y='y',
    shade=True,
    shade_lowest=False,
    alpha=0.5,
    n_levels=10,
    cmap='cmr.pride',
    ax=ax  # Pass the Axes object to draw the KDE plot on the pitch
)

# Show the plot
plt.show()

plot_heatmap(187861)
# Out:
# /var/folders/8_/_mkv7dtj7hvfvhvj31qsy35h0000gn/T/ipykernel_36976/47156337.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde = sns.kdeplot(
# /Users/calvi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/calvi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/calvi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/calvi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
